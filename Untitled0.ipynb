# %% [markdown]
# <a href="https://colab.research.google.com/github/Edward-The-Great/Matala-3/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this notebook, I've worked with a dataset focused on medical data, specifically aimed at predicting diabetes outcomes. This dataset provides a rich set of independent variables which are known medical predictors of diabetes, including:
#
# **Number of Pregnancies**: How many times the patient has been pregnant, which can influence diabetes risk.
#
# **BMI** (Body Mass Index): A measure that uses height and weight to gauge body fat, with higher values correlating with increased diabetes risk.**bold text**
#
# **Insulin Level**: Reflects how well the body manages blood sugar, where abnormal levels can indicate diabetes or pre-diabetes.
#
# **Age**: Since diabetes risk increases with age, this is a significant predictor.
#
# **Other variables**: Including but not limited to blood pressure, glucose levels, and skin thickness.
#
# The ***target variable*** here is 'Outcome', a binary indicator of whether or not the patient has diabetes (1) or not (0).
#
# in this section i focus on:
#
# **Data Exploration:** To understand the distribution and relationships among these variables.
# Data Preprocessing: Handling any missing or inconsistent data to prepare for model training.
#
# **Model Selection and Training:**
# The final target of the study (later on)
#  Implementing and comparing three classification algorithms - K-Nearest Neighbors, Naive Bayes, and Decision Trees - to predict the Outcome based on the given predictors.
#
# so now i am making first steps via exploring and cleaning the data
#
# Thank you for reviewing my work."
# Edward Shine

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv(r'/content/drive/MyDrive/DATAset/diabetes.csv')
df.head(13)
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# my first action is to try the default plot, as we learned in class. while it is cool to see immediate results, actually it is yet hard to import meaninfull onformation, so i will give it another edit:

# %%
#  specific columns for plotting
columns_to_plot = ['Pregnancies', 'Glucose', 'BMI', 'Age']
# Plot only the selected columns
df[columns_to_plot].plot()
# Show the plot
plt.show()

# %% [markdown]
# ok, this is better, but still do not tell much. i will adress it later.
#
# now, i will try one of them scatter graphs. i will try to see glucose relatonship vs outcome = sick or healthy individual

# %%
df.plot(kind='scatter', x='Outcome',y='Glucose', title='glucose vs. sick')
# Out:
# <Axes: title={'center': 'glucose vs. sick'}, xlabel='Outcome', ylabel='Glucose'>

# %% [markdown]
# unfortunatly, this distirbution is not teching us something meaninfull, ill try another approach: lets see if there is some relationship between glucose and blood pressure:

# %%
df.plot(kind='scatter', x='BloodPressure',y='Glucose', title='glucose vs. blood pressure')
# Out:
# <Axes: title={'center': 'glucose vs. blood pressure'}, xlabel='BloodPressure', ylabel='Glucose'>

# %% [markdown]
# ok good start, maybe ill learn something valuable for knn later on!

# %% [markdown]
# now lets try the histogram of glucose

# %%
df["Glucose"].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# nice!

# %% [markdown]
# now is the time to add pie chart

# %%
activities = ['eat', 'sleep', 'work', 'play']
slices = [1, 7, 8, 6]
colors = ['r', 'y', 'g', 'b']
plt.pie(slices, labels = activities, colors=colors, explode = (0, 0, 0.1, 0),
radius = 1.2, autopct = '%.1f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# that's cool, but the pie is not connected with the info or the dataset! i need to find a way to correlate them

# %% [markdown]
# for coclusion of this section:
# i am very excited to make the first use of plotting tools like
# a)default plot
# b)edited plot
# c)scatter plot
# d)histogram
# e)pie chart
#
# as an experienced architect i used some graphic tools, for so many times for years, but it was all a lie!:))))))) because it was always ilustrations, and wasn't dispaly of an actual data like in this study case. so indeed, this is very promising and inspiring!
# Thanks again, for reviewing my work! Edward Shine
